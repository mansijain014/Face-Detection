# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread("/content/GP6.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
import cv2

# %%
model = cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")

# %%
faces = model.detectMultiScale(img)

# %%
faces.shape
# Out:
# (6, 4)

# %%
# This means there are 6 faces

# %%
faces
# Out:
# array([[234,  32,  36,  36],
#        [149,  25,  34,  34],
#        [ 22,  41,  34,  34],
#        [ 86,  28,  40,  40],
#        [124,  53,  31,  31],
#        [211,  53,  32,  32]], dtype=int32)

# %%
for face in faces:
  x,y,w,h = face
  img = cv2.rectangle(img, (x,y),(x+w,y+h),(255,0,0),1)
  plt.imshow(img)

# %%
faces
# Out:
# array([[149,  25,  34,  34],
#        [ 86,  28,  40,  40],
#        [234,  32,  36,  36],
#        [ 22,  41,  34,  34],
#        [124,  53,  31,  31],
#        [211,  53,  32,  32]], dtype=int32)

# %%
for face in faces:
   x,y,w,h = face
   img1 = cv2.rectangle(img1, (x,y),(x+w,y+h),(180,0,0),1)
   plt.imshow(img1)
